# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("loan_approval_dataset.csv")

# %%
dataset.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
dataset.shape
# Out:
# (4269, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
dataset.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
pd.crosstab(dataset[' loan_amount'], dataset[' loan_status'], margins=True)
# Out:
#  loan_status   Approved   Rejected   All
#  loan_amount
# 300000                2          4     6
# 400000                7          0     7
# 500000                9          7    16
# 600000                7          6    13
# 700000               11          4    15
# ...                 ...        ...   ...
# 38500000              1          0     1
# 38700000              2          0     2
# 38800000              1          0     1
# 39500000              1          0     1
# All                2656       1613  4269
#
# [379 rows x 3 columns]

# %%
import pandas as pd

# %%
dataset.boxplot(column=' income_annum')
# Out:
# <Axes: >

# %%
dataset[' income_annum'].hist()
# Out:
# <Axes: >

# %%
dataset.boxplot(column=' income_annum', by=' residential_assets_value')
# Out:
# <Axes: title={'center': ' income_annum'}, xlabel=' residential_assets_value'>

# %%
dataset.boxplot(column=' loan_amount')
# Out:
# <Axes: >

# %%
dataset[' loan_amount'].hist(bins=20)
# Out:
# <Axes: >

# %%
dataset[' loan_amount_log']=np.log(dataset[' loan_amount'])
dataset[' loan_amount_log'].hist(bins=20)
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
#  loan_amount_log             0
# dtype: int64

# %%
dataset.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
import pandas as pd

x = dataset.iloc[:,np.r_[1:5,1:10,2:10]].values
y = dataset.iloc[:,12].values

# Calculate descriptive statistics for x
x_df = pd.DataFrame(x)
x_df.describe()

# Calculate descriptive statistics for y
y_df = pd.DataFrame(y)
y_df.describe()
# Out:
#                 0
# count        4269
# unique          2
# top      Approved
# freq         2656

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split



# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print(X_train)
# Out:
# [[2 ' Graduate' ' Yes' ... 547 5000000 1700000]
#  [1 ' Not Graduate' ' Yes' ... 378 18600000 1000000]
#  [2 ' Not Graduate' ' No' ... 601 300000 3100000]
#  ...
#  [3 ' Not Graduate' ' Yes' ... 684 17200000 10300000]
#  [4 ' Not Graduate' ' No' ... 786 300000 2500000]
#  [1 ' Not Graduate' ' Yes' ... 711 6300000 7600000]]

# %%
from sklearn import preprocessing

# Create a LabelEncoder object
label_encoder_X = preprocessing.LabelEncoder()

# %%
for i in range(0, 5):X_train[:,i] =label_encoder_X.fit_transform(X_train[:,i])

# %%
X_train[:,7] =label_encoder_X.fit_transform(X_train[:,7])

# %%
X_train
# Out:
# array([[2, 0, 1, ..., 547, 5000000, 1700000],
#        [1, 1, 1, ..., 378, 18600000, 1000000],
#        [2, 1, 0, ..., 601, 300000, 3100000],
#        ...,
#        [3, 1, 1, ..., 684, 17200000, 10300000],
#        [4, 1, 0, ..., 786, 300000, 2500000],
#        [1, 1, 1, ..., 711, 6300000, 7600000]], dtype=object)

# %%
label_encoder_y = preprocessing.LabelEncoder()
y_train = label_encoder_y.fit_transform(y_train)

# %%
y_train
# Out:
# array([1, 1, 0, ..., 0, 0, 0])
